# %% [markdown]
# # 안녕하세요^^
# ## AIVLE 미니프로젝트 '서울시 생활정보 기반 대중교통 수요 분석 ' 과정에 오신 여러분을 환영합니다.
# * 본 과정에서는 실제 사례와 데이터를 기반으로 문제를 해결하는 전체 과정을 자기 주도형 실습으로 진행해볼 예정입니다.
# * 앞선 교육과정을 정리하는 마음과 지금까지 배운 내용을 바탕으로 문제 해결을 해볼게요!
# * 미니 프로젝트를 통한 문제 해결 과정 'A에서 Z까지', 지금부터 시작합니다!
#
# ## 개인과제
# * 데이터 구조, 분포 확인, 전처리 : 1.1_버스정류장데이터 / 1.2 유동인구데이터 / 1.3_주민등록데이터 / 1.4_업종등록데이터
# * 데이터간 관계 가설 수립 및 검증 : 1.5_데이터 분석

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 분석부터 먼저 시작해보겠습니다.
# ## "구별 업종 등록 데이터" 를 확인해 보도록 하겠습니다

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 기본/추가 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * business_type.csv
#
# [데이터 소개]
# * 서울 시 구별 등록 업종 상위 10개 데이터
#     * 택시운송업
#     * 한식일반음식점업
#     * 용달 화물자동차 운송업
#     * 부동산 중개 및 대리업
#     * 두발미용업
#     * 커피전문점
#     * 남녀용 겉옷 및 셔츠 도매업
#     * 기타주점업
#     * 일반 교과 학원
#     * 한식 육류요리 전문점
#
# [변수 소개]
# * 다수 업종 상위 1~10

# %% [markdown]
# ---

# %% [markdown]
# # 1.데이터 불러오기
# ## 모든 미니 프로젝트의 시작은 '데이터 불러오기' 부터라고 할 수 있습니다.
# + KeyPoint : 불러오고자 하는 데이터에 따라 자유롭게 변수로 지정할 수 있다.

# %% [markdown]
# ###  데이터 프레임을 불러오고 변수로 저장(여기서는 CSV 기준으로 진행)
# * csv : pd.read_csv("파일이름. csv")
# * txt : pd.read_csv("파일이름. csv", sep="구분자")
# * xlsx : pd.read_excel('파일이름.xlsx')
# * pickle : pd.read_pickle("파일이름.pkl") <br>
#  [참고] pickle은 파이썬의 모든 객체를 파일로 저장할 수 있는 방법으로 DataFrame,List,Dict 등 모든 객체 저장 가능(특히 sklearn라이브러리를 통해 모델을 학습시키고, 저장할 때 많이 사용)

# %% [markdown]
# ## 기본전제
# * 처음에 제공되는 데이터는 'raw_data' 폴더에 있습니다.
#
# [기본 데이터]
# * 1.4 business_type.csv
#
# [데이터 소개]
# * 서울시 업종 등록 데이터

# %% [markdown]
# #### [실습문제1] 데이터 로딩
# * '1.4 business_type.csv'파일을 'seoul_business' 변수에 저장하고 그 데이터를 확인하세요.
#     * 데이터 파일 로딩시 참고 사항
#         * 구분자(sep)는 ',' 입니다
#         * UTF-8 인코더를 사용해 주세요

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
import pandas as pd
seoul_business = pd.read_csv("1.4 business_type.csv", sep = ",", encoding = "UTF-8", header = 1) #0번째 인덱스(행)가 header == 1

# %%
pd.set_option("display.max_columns", None)

# %%
seoul_business
# Out:
#      자치구     동   택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# 0    자치구     동    사업체수    종사자수       사업체수         종사자수         사업체수
# 1     합계    합계  47,176  76,701     29,225      100,183       28,494
# 2    종로구    소계     215     215      1,548        5,912          618
# 3    종로구   사직동       7       7        230          982           12
# 4    종로구   삼청동       5       5         42          145            4
# ..   ...   ...     ...     ...        ...          ...          ...
# 445  강동구  성내3동     120     120        135          390           73
# 446  강동구  둔촌2동     117     436         63          249           89
# 447  강동구  암사1동     209     372         71          195          153
# 448  강동구  천호2동     157     187        152          509          144
# 449  강동구    길동   1,441   1,557        152          436          217
#
#     용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1   두발미용업 두발미용업.1   커피전문점  \
# 0             종사자수         사업체수           종사자수    사업체수    종사자수    사업체수
# ...

# %%
# 데이터 프레임의 Shape을 확인합니다.
seoul_business.shape
# Out:
# (450, 22)

# %% [markdown]
# ---

# %% [markdown]
# # 2.기본 정보 확인 및 클렌징
#
# + 데이터 클렌징 : 결측치, 이상치 등을 제거하여 데이터 분석 결과가 왜곡 되는 문제를 방지하기 위한 정제 과정

# %% [markdown]
# #### [실습문제2] 기본 정보 확인하기
# * 'seoul_business' 데이터의 정보를 확인해보세요.
# * 'describe', 'info', 'head' 등 전부 활용해 보겠습니다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   자치구                450 non-null    object
#  1   동                  450 non-null    object
#  2   택시운송업              450 non-null    object
#  3   택시운송업.1            450 non-null    object
#  4   한식 일반 음식점업         450 non-null    object
#  5   한식 일반 음식점업.1       450 non-null    object
#  6   용달 화물자동차 운송업       450 non-null    object
#  7   용달 화물자동차 운송업.1     450 non-null    object
#  8   부동산 중개 및 대리업       450 non-null    object
#  9   부동산 중개 및 대리업.1     450 non-null    object
#  10  두발미용업              450 non-null    object
#  11  두발미용업.1            450 non-null    object
#  12  커피전문점              450 non-null    object
#  13  커피전문점.1            450 non-null    object
#  14  남녀용 겉옷 및 셔츠 도매업    450 non-null    object
#  15  남녀용 겉옷 및 셔츠 도매업.1  450 non-null    object
# ...

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business.describe()
# Out:
#         자치구    동 택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# count   450  450   450     450        450          450          450
# unique   27  425   225     279        175          304          176
# top     송파구   소계    11      11         24           85           27
# freq     28   25     7       7         11            6            8
#
#        용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1 두발미용업 두발미용업.1 커피전문점 커피전문점.1  \
# count             450          450            450   450     450   450     450
# unique            179          141            204   120     179   130     238
# top                56           40             64    46      47    13      16
# freq                9           11              9    12      10    18       8
#
#        남녀용 겉옷 및 셔츠 도매업 남녀용 겉옷 및 셔츠 도매업.1 기타주점업 기타주점업.1 일반 교과 학원 일반 교과 학원.1  \
# count              450               450   450     450      450        450
# unique              68               146   126     188      112        221
# ...

# %%
seoul_business.tail()
# Out:
#      자치구     동  택시운송업 택시운송업.1 한식 일반 음식점업 한식 일반 음식점업.1 용달 화물자동차 운송업  \
# 445  강동구  성내3동    120     120        135          390           73
# 446  강동구  둔촌2동    117     436         63          249           89
# 447  강동구  암사1동    209     372         71          195          153
# 448  강동구  천호2동    157     187        152          509          144
# 449  강동구    길동  1,441   1,557        152          436          217
#
#     용달 화물자동차 운송업.1 부동산 중개 및 대리업 부동산 중개 및 대리업.1 두발미용업 두발미용업.1 커피전문점 커피전문점.1  \
# 445             73          104            163    83     113    54     133
# 446             89           61            108    62      75    34      85
# 447            153           67            107    82     114    29      59
# 448            151           97            188    83     168    63     212
# 449            225          146            237   121     193    71     228
#
#     남녀용 겉옷 및 셔츠 도매업 남녀용 겉옷 및 셔츠 도매업.1 기타주점업 기타주점업.1 일반 교과 학원 일반 교과 학원.1  \
# ...

# %% [markdown]
# #### [실습문제3] 데이터 확인 및 처리
#
# * 데이터를 보았을때, 어느 데이터를 가져와야 할지 생각 해 봅시다.

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business = seoul_business.iloc[:,[0, 1, 4, 12, 16, 20]]
seoul_business.head()
# Out:
#    자치구    동 한식 일반 음식점업   커피전문점   기타주점업 한식 육류요리 전문점
# 0  자치구    동       사업체수    사업체수    사업체수        사업체수
# 1   합계   합계     29,225  16,255  13,339      11,109
# 2  종로구   소계      1,548     948     537         437
# 3  종로구  사직동        230     124      74          45
# 4  종로구  삼청동         42      66       3           7

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
seoul_business = seoul_business[seoul_business["동"] == "소계"].reset_index(drop = True)

# %%
seoul_business = seoul_business.drop("동", axis = 1)

# %%
seoul_business
# Out:
#      자치구 한식 일반 음식점업.1 커피전문점.1 기타주점업.1 일반 교과 학원.1 한식 육류요리 전문점.1
# 0    종로구        5,912   3,613   1,413        382         1,982
# 1     중구        6,414   3,542     982        175         2,121
# 2    용산구        2,987   2,076   1,332        573         1,184
# 3    성동구        2,785   1,859     621      1,494         1,545
# 4    광진구        2,861   1,887   1,577      1,646         1,678
# 5   동대문구        3,566   1,472   1,082        984         1,509
# 6    중랑구        2,479   1,037   1,000      1,045         1,504
# 7    성북구        2,822   1,384   1,030      1,755         1,334
# 8    강북구        2,663   1,095   1,275        740         1,176
# 9    도봉구        2,009     837     477      1,162           943
# 10   노원구        2,650   1,748     844      3,281         1,557
# 11   은평구        2,585   1,296     925      1,793         1,639
# 12  서대문구        2,694   1,323   1,127      1,268         1,088
# 13   마포구        4,705   4,475   2,559      1,855         2,928
# ...

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.
seoul_business.to_csv("df_seoul_business.csv", index = False)

# %%
abcd = pd.read_csv("df_seoul_business.csv", sep = ",", encoding = "UTF-8", thousands = ",")

# %%
abcd["총합"] = abcd["한식 일반 음식점업.1"] + abcd["기타주점업.1"] + abcd["커피전문점.1"] + abcd["일반 교과 학원.1"] + abcd["한식 육류요리 전문점.1"]

# %%
abcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   자치구            25 non-null     object
#  1   한식 일반 음식점업.1   25 non-null     int64
#  2   커피전문점.1        25 non-null     int64
#  3   기타주점업.1        25 non-null     int64
#  4   일반 교과 학원.1     25 non-null     int64
#  5   한식 육류요리 전문점.1  25 non-null     int64
#  6   총합             25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
# 해당 데이터프레임을 'df_seoul_business.csv' 파일로 저장하세요.
abcd.to_csv("df_seoul_business.csv", index = False)

# %% [markdown]
# ---

# %% [markdown]
# # 3.데이터 분석하기
# + KeyPoint : 데이터의 형태를 살펴보고 다양한 분석기법을 통해 모델링에 적합하도록 정제요소를 선별할 수 있다.
#   * 데이터들의 패턴 탐색
#   * 변수들간의 관계 파악

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 시각화 한글폰트 설정
# 맑은 고딕

plt.rc('font', family='Malgun Gothic')
sns.set(font="Malgun Gothic",#"NanumGothicCoding", 
        rc={"axes.unicode_minus":False}, # 마이너스 부호 깨짐 현상 해결
        style='darkgrid')

# scipy
import scipy.stats as spst

# %% [markdown]
# #### [실습문제4] 데이터 분포 알아보기
# * 다양한 변수를 기준으로 그래프를 그려보고 인사이트를 도출해보세요.

# %%
temp = seoul_business.sort_values("기타주점업.1")

# %%
temp
# Out:
#      자치구 한식 일반 음식점업.1 커피전문점.1 기타주점업.1 일반 교과 학원.1 한식 육류요리 전문점.1
# 6    중랑구        2,479   1,037   1,000      1,045         1,504
# 7    성북구        2,822   1,384   1,030      1,755         1,334
# 5   동대문구        3,566   1,472   1,082        984         1,509
# 12  서대문구        2,694   1,323   1,127      1,268         1,088
# 16   구로구        3,215   1,384   1,165      1,111         1,496
# 21   서초구        6,712   3,897   1,255      3,812         2,338
# 8    강북구        2,663   1,095   1,275        740         1,176
# 2    용산구        2,987   2,076   1,332        573         1,184
# 24   강동구        3,388   1,660   1,349      2,104         1,459
# 0    종로구        5,912   3,613   1,413        382         1,982
# 23   송파구        5,760   3,372   1,469      4,160         2,781
# 18  영등포구        6,476   3,295   1,489      1,082         2,151
# 4    광진구        2,861   1,887   1,577      1,646         1,678
# 20   관악구        3,689   2,049   1,672      1,230         1,628
# ...

# %%
temp = temp.astype({"기타주점업.1" : "float"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 temp = temp.astype({"기타주점업.1" : "float"})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5898, in NDFrame.astype(self, dtype, copy, errors)
#    5896             res_col = col.copy() if copy else col
#    5897         else:
# -> 5898             res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899         results.append(res_col)
#    5901 elif is_extension_array_dtype(dtype) and self.ndim > 1:
#    5902     # GH 18099/22869: columnwise conversion to extension dtype
#    5903     # GH 24704: use iloc to handle duplicate column names
#    5904     # TODO(EA2D): special case not needed with 2D EAs
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
# ...

# %%
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 25 entries, 6 to 1
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   자치구            25 non-null     object
#  1   한식 일반 음식점업.1   25 non-null     object
#  2   커피전문점.1        25 non-null     object
#  3   기타주점업.1        25 non-null     object
#  4   일반 교과 학원.1     25 non-null     object
#  5   한식 육류요리 전문점.1  25 non-null     object
# dtypes: object(6)
# memory usage: 1.4+ KB

# %%
# 아래에 실습코드를 작성하고 결과를 확인합니다.
plt.figure(figsize = (20, 7))
plt.plot("자치구", "기타주점업.1", "-o", data = temp)
plt.show()

# %% [markdown]
# - 각 업종 기준 자치구별 합계를 시각화해서 분석하고 싶은데 그래프가 이상하게 나온다..
#     - 알고보니 업종 열이 string 형식이고 1000이상은 쉼표로 자릿수 나눠서 쉼표 제거 후 형변환해서 시각화 해야하는데 쉼표 제거가 안된다.. replace도 안먹히고

# %%
abcd = pd.read_csv("df_seoul_business.csv", sep = ",", encoding = "UTF-8", thousands = ",")

# %%
abcd["총합"] = abcd["한식 일반 음식점업.1"] + abcd["기타주점업.1"] + abcd["커피전문점.1"] + abcd["일반 교과 학원.1"] + abcd["한식 육류요리 전문점.1"]

# %%
abcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   자치구            25 non-null     object
#  1   한식 일반 음식점업.1   25 non-null     int64
#  2   커피전문점.1        25 non-null     int64
#  3   기타주점업.1        25 non-null     int64
#  4   일반 교과 학원.1     25 non-null     int64
#  5   한식 육류요리 전문점.1  25 non-null     int64
#  6   총합             25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
plt.figure(figsize = (20, 7))
plt.plot("자치구", "기타주점업.1", "-o", data = abcd)
plt.plot("자치구", "커피전문점.1", "-o", data = abcd)
plt.plot("자치구", "일반 교과 학원.1", "-o", data = abcd)
plt.plot("자치구", "한식 일반 음식점업.1", "-o", data = abcd)
plt.plot("자치구", "한식 육류요리 전문점.1", "-o", data = abcd)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (20, 7))
plt.plot("자치구", "총합", "-o", data = abcd)
plt.legend()
plt.show()

# %% [markdown]
# - read_csv에 저런 기능이 있을 줄이야.. 덕분에 시각화했다
# - 인기 업종 합계를 구해도 광진구가 성동구보다 많다.. 그러므로 버스정류장이나 버스 노선 추가

# %% [markdown]
# ---
